# %% [markdown]
# # Introduction
#
# in this project i will create an imdb scraper to get information about the top movies sorted by the number of votes that has been released between **2000-01-01** and **2018-12-31**, I'm going to extract data such as votes, meta score and year, I will extract the data needed using a library called **BeautifulSoup** and to get information about a website we use get in the **requests** library.

# %% [markdown]
# # Importing the required libraries

# %%
import pandas as pd
import numpy as np
from requests import get # Retrieving information in a website
from bs4 import BeautifulSoup # Extracting data
from time import time # calculate the time
from time import sleep # pause the loop
from random import randint # Randomize sleep time
from IPython.core.display import clear_output # Stack the output
from warnings import warn # Warn when something goes wrong

# %% [markdown]
# # Getting the url
#
# Retrieving informations about the url and checking if it's working.

# %%
# Store the url we will get data from
url = 'https://www.imdb.com/search/title?title_type=feature&release_date=2018-01-01,2018-12-31&sort=num_votes,desc&start=01&ref_=adv_nxt'
# Request for the content of the url
response = get(url)
# Print out to check if it work
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
#         <title>IMDb: Feature Film,
# Released between 2018-01-01 and 2018-12-31
# (Sorted by Number of Votes Descending) - IMDb</title>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </scri

# %% [markdown]
# # Parsing the HTML and getting the data

# %%
# Parsing response to HTML
html = BeautifulSoup(response.text, 'html.parser')
# Print out the html to understand the structure and retrive data.
print(html.prettify()[35000:65000])
# Out:
# 3A//www.imdb.com/search/title%3Ftitle_type%3Dfeature%26release_date%3D2018-01-01,2018-12-31%26sort%3Dnum_votes,desc%26start%3D01%26ref_%3Dadv_nxt&amp;ref_=nv_generic_lgin" id="imdb-signin-link">
#            <span class="signin-imdb-text">
#             Sign in
#            </span>
#           </a>
#          </p>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ne");
#     }
#      </script>
#      <!-- no content received for slot: navstrip -->
#      <!-- no content received for slot: injected_navstrip -->
#     </div>
#     <div class="pagecontent" id="pagecontent">
#      <!-- no content received for slot: injected_billboard -->
#      <style type="text/css">
#       .companyBanner {
#     padding: 0px 12px;
#   }
#      </style>
#      <div class="redesign" id="content-2-wide">
#       <div id="main">
#        <div class="article">
#         <h1 class="header">
#          Feature Film,
# Released between 2018-01-01 and 2018-12-31
# (Sorted by Number of Votes Descending)
#         </h1>
#         <div class="nav">
#          <br class="clear"/>
#          <div class="display-mode float-right">
#           View Mode:
#           <a class="compact" href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=num_votes,desc&amp;view=simple">
#            Compact
#           </a>
#           <span class="ghost">
#            |
#           </span>
#           <a class="detailed" href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=num_votes,desc&amp;view=advanced">
#            <strong>
#             Detailed
#            </strong>
#           </a>
#          </div>
#          <div class="desc">
#           <span>
#            1-50 of 12,196 titles.
#           </span>
#           <span class="ghost">
#            |
#           </span>
#           <a class="lister-page-next next-page" href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=num_votes,desc&amp;start=51&amp;ref_=adv_nxt">
#            Next »
#           </a>
#          </div>
#         </div>
#         <br class="clear"/>
#         <div class="sorting">
#          Sort by:
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31">
#           Popularity
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=alpha,asc">
#           A-Z
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=user_rating,desc">
#           User Rating
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=num_votes,asc">
#           <strong>
#            Number of Votes
#           </strong>
#           ▼
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=boxoffice_gross_us,asc">
#           US Box Office
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=runtime,asc">
#           Runtime
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=year,asc">
#           Year
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=release_date,asc">
#           Release Date
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=your_rating_date,asc">
#           Date of Your Rating
#          </a>
#          <span class="ghost">
#           |
#          </span>
#          <a href="/search/title?title_type=feature&amp;release_date=2018-01-01,2018-12-31&amp;sort=my_ratings,desc">
#           Your Rating
#          </a>
#         </div>
#         <br class="clear"/>
#         <div class="lister list detail sub-list">
#          <div class="lister-list">
#           <div class="lister-item mode-advanced">
#            <div class="lister-top-right">
#             <div class="ribbonize" data-caller="filmosearch" data-tconst="tt4154756">
#             </div>
#            </div>
#            <div class="lister-item-image float-left">
#             <a href="/title/tt4154756/?ref_=adv_li_i">
#              <img alt="Avengers: Infinity War" class="loadlate" data-tconst="tt4154756" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#             </a>
#            </div>
#            <div class="lister-item-content">
#             <h3 class="lister-item-header">
#              <span class="lister-item-index unbold text-primary">
#               1.
#              </span>
#              <a href="/title/tt4154756/?ref_=adv_li_tt">
#               Avengers: Infinity War
#              </a>
#              <span class="lister-item-year text-muted unbold">
#               (2018)
#              </span>
#             </h3>
#             <p class="text-muted ">
#              <span class="certificate">
#               PG-13
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="runtime">
#               149 min
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="genre">
#               Action, Adventure, Fantasy
#              </span>
#             </p>
#             <div class="ratings-bar">
#              <div class="inline-block ratings-imdb-rating" data-value="8.5" name="ir">
#               <span class="global-sprite rating-star imdb-rating">
#               </span>
#               <strong>
#                8.5
#               </strong>
#              </div>
#              <div class="inline-block ratings-user-rating">
#               <span class="userRatingValue" data-tconst="tt4154756" id="urv_tt4154756">
#                <span class="global-sprite rating-star no-rating">
#                </span>
#                <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">
#                 Rate this
#                </span>
#               </span>
#               <div class="starBarWidget" id="sb_tt4154756">
#                <div class="rating rating-list" data-auth="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt4154756|imdb|8.5|8.5|||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.5/10 (589,794 votes) - click stars to rate">
#                 <meta content="8.5" itemprop="ratingValue"/>
#                 <meta content="10" itemprop="bestRating"/>
#                 <meta content="589794" itemprop="ratingCount"/>
#                 <span class="rating-bg">
#                 </span>
#                 <span class="rating-imdb " style="width: 119px">
#                 </span>
#                 <span class="rating-stars">
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    1
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    2
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    3
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    4
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    5
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    6
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    7
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    8
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    9
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    10
#                   </span>
#                  </a>
#                 </span>
#                 <span class="rating-rating ">
#                  <span class="value">
#                   8.5
#                  </span>
#                  <span class="grey">
#                   /
#                  </span>
#                  <span class="grey">
#                   10
#                  </span>
#                 </span>
#                 <span class="rating-cancel ">
#                  <a href="/title/tt4154756/vote?v=X;k=" rel="nofollow" title="Delete">
#                   <span>
#                    X
#                   </span>
#                  </a>
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div class="inline-block ratings-metascore">
#               <span class="metascore favorable">
#                68
#               </span>
#               Metascore
#              </div>
#             </div>
#             <p class="text-muted">
#              The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.
#             </p>
#             <p class="">
#              Directors:
#              <a href="/name/nm0751577/?ref_=adv_li_dr_0">
#               Anthony Russo
#              </a>
#              ,
#              <a href="/name/nm0751648/?ref_=adv_li_dr_1">
#               Joe Russo
#              </a>
#              <span class="ghost">
#               |
#              </span>
#              Stars:
#              <a href="/name/nm0000375/?ref_=adv_li_st_0">
#               Robert Downey Jr.
#              </a>
#              ,
#              <a href="/name/nm1165110/?ref_=adv_li_st_1">
#               Chris Hemsworth
#              </a>
#              ,
#              <a href="/name/nm0749263/?ref_=adv_li_st_2">
#               Mark Ruffalo
#              </a>
#              ,
#              <a href="/name/nm0262635/?ref_=adv_li_st_3">
#               Chris Evans
#              </a>
#             </p>
#             <p class="sort-num_votes-visible">
#              <span class="text-muted">
#               Votes:
#              </span>
#              <span data-value="589794" name="nv">
#               589,794
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="text-muted">
#               Gross:
#              </span>
#              <span data-value="678,815,482" name="nv">
#               $678.82M
#              </span>
#             </p>
#            </div>
#           </div>
#           <div class="lister-item mode-advanced">
#            <div class="lister-top-right">
#             <div class="ribbonize" data-caller="filmosearch" data-tconst="tt1825683">
#             </div>
#            </div>
#            <div class="lister-item-image float-left">
#             <a href="/title/tt1825683/?ref_=adv_li_i">
#              <img alt="Black Panther" class="loadlate" data-tconst="tt1825683" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#             </a>
#            </div>
#            <div class="lister-item-content">
#             <h3 class="lister-item-header">
#              <span class="lister-item-index unbold text-primary">
#               2.
#              </span>
#              <a href="/title/tt1825683/?ref_=adv_li_tt">
#               Black Panther
#              </a>
#              <span class="lister-item-year text-muted unbold">
#               (2018)
#              </span>
#             </h3>
#             <p class="text-muted ">
#              <span class="certificate">
#               PG-13
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="runtime">
#               134 min
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="genre">
#               Action, Adventure, Sci-Fi
#              </span>
#             </p>
#             <div class="ratings-bar">
#              <div class="inline-block ratings-imdb-rating" data-value="7.3" name="ir">
#               <span class="global-sprite rating-star imdb-rating">
#               </span>
#               <strong>
#                7.3
#               </strong>
#              </div>
#              <div class="inline-block ratings-user-rating">
#               <span class="userRatingValue" data-tconst="tt1825683" id="urv_tt1825683">
#                <span class="global-sprite rating-star no-rating">
#                </span>
#                <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">
#                 Rate this
#                </span>
#               </span>
#               <div class="starBarWidget" id="sb_tt1825683">
#                <div class="rating rating-list" data-auth="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt1825683|imdb|7.3|7.3|||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 7.3/10 (465,635 votes) - click stars to rate">
#                 <meta content="7.3" itemprop="ratingValue"/>
#                 <meta content="10" itemprop="bestRating"/>
#                 <meta content="465635" itemprop="ratingCount"/>
#                 <span class="rating-bg">
#                 </span>
#                 <span class="rating-imdb " style="width: 102.2px">
#                 </span>
#                 <span class="rating-stars">
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    1
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    2
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    3
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    4
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    5
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    6
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    7
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    8
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    9
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    10
#                   </span>
#                  </a>
#                 </span>
#                 <span class="rating-rating ">
#                  <span class="value">
#                   7.3
#                  </span>
#                  <span class="grey">
#                   /
#                  </span>
#                  <span class="grey">
#                   10
#                  </span>
#                 </span>
#                 <span class="rating-cancel ">
#                  <a href="/title/tt1825683/vote?v=X;k=" rel="nofollow" title="Delete">
#                   <span>
#                    X
#                   </span>
#                  </a>
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div class="inline-block ratings-metascore">
#               <span class="metascore favorable">
#                88
#               </span>
#               Metascore
#              </div>
#             </div>
#             <p class="text-muted">
#              T'Challa, heir to the hidden but advanced kingdom of Wakanda, must step forward to lead his people into a new future and must confront a challenger from his country's past.
#             </p>
#             <p class="">
#              Director:
#              <a href="/name/nm3363032/?ref_=adv_li_dr_0">
#               Ryan Coogler
#              </a>
#              <span class="ghost">
#               |
#              </span>
#              Stars:
#              <a href="/name/nm1569276/?ref_=adv_li_st_0">
#               Chadwick Boseman
#              </a>
#              ,
#              <a href="/name/nm0430107/?ref_=adv_li_st_1">
#               Michael B. Jordan
#              </a>
#              ,
#              <a href="/name/nm2143282/?ref_=adv_li_st_2">
#               Lupita Nyong'o
#              </a>
#              ,
#              <a href="/name/nm1775091/?ref_=adv_li_st_3">
#               Danai Gurira
#              </a>
#             </p>
#             <p class="sort-num_votes-visible">
#              <span class="text-muted">
#               Votes:
#              </span>
#              <span data-value="465635" name="nv">
#               465,635
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="text-muted">
#               Gross:
#              </span>
#              <span data-value="700,059,566" name="nv">
#               $700.06M
#              </span>
#             </p>
#            </div>
#           </div>
#           <div class="lister-item mode-advanced">
#            <div class="lister-top-right">
#             <div class="ribbonize" data-caller="filmosearch" data-tconst="tt5463162">
#             </div>
#            </div>
#            <div class="lister-item-image float-left">
#             <a href="/title/tt5463162/?ref_=adv_li_i">
#              <img alt="Deadpool 2" class="loadlate" data-tconst="tt5463162" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNjk1Njk3YjctMmMyYS00Y2I4LThhMzktN2U0MTMyZTFlYWQ5XkEyXkFqcGdeQXVyODM2ODEzMDA@._V1_UY98_CR15,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#             </a>
#            </div>
#            <div class="lister-item-content">
#             <h3 class="lister-item-header">
#              <span class="lister-item-index unbold text-primary">
#               3.
#              </span>
#              <a href="/title/tt5463162/?ref_=adv_li_tt">
#               Deadpool 2
#              </a>
#              <span class="lister-item-year text-muted unbold">
#               (2018)
#              </span>
#             </h3>
#             <p class="text-muted ">
#              <span class="certificate">
#               R
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="runtime">
#               119 min
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="genre">
#               Action, Adventure, Comedy
#              </span>
#             </p>
#             <div class="ratings-bar">
#              <div class="inline-block ratings-imdb-rating" data-value="7.8" name="ir">
#               <span class="global-sprite rating-star imdb-rating">
#               </span>
#               <strong>
#                7.8
#               </strong>
#              </div>
#              <div class="inline-block ratings-user-rating">
#               <span class="userRatingValue" data-tconst="tt5463162" id="urv_tt5463162">
#                <span class="global-sprite rating-star no-rating">
#                </span>
#                <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">
#                 Rate this
#                </span>
#               </span>
#               <div class="starBarWidget" id="sb_tt5463162">
#                <div class="rating rating-list" data-auth="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt5463162|imdb|7.8|7.8|||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 7.8/10 (351,483 votes) - click stars to rate">
#                 <meta content="7.8" itemprop="ratingValue"/>
#                 <meta content="10" itemprop="bestRating"/>
#                 <meta content="351483" itemprop="ratingCount"/>
#                 <span class="rating-bg">
#                 </span>
#                 <span class="rating-imdb " style="width: 109.2px">
#                 </span>
#                 <span class="rating-stars">
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    1
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    2
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    3
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    4
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    5
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    6
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    7
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    8
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    9
#                   </span>
#                  </a>
#                  <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#                   <span>
#                    10
#                   </span>
#                  </a>
#                 </span>
#                 <span class="rating-rating ">
#                  <span class="value">
#                   7.8
#                  </span>
#                  <span class="grey">
#                   /
#                  </span>
#                  <span class="grey">
#                   10
#                  </span>
#                 </span>
#                 <span class="rating-cancel ">
#                  <a href="/title/tt5463162/vote?v=X;k=" rel="nofollow" title="Delete">
#                   <span>
#                    X
#                   </span>
#                  </a>
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div class="inline-block ratings-metascore">
#               <span class="metascore favorable">
#                66
#               </span>
#               Metascore
#              </div>
#             </div>
#             <p class="text-muted">
#              Foul-mouthed mutant mercenary Wade Wilson (AKA. Deadpool), brings together a team of fellow mutant rogues to protect a young boy with supernatural abilities from the brutal, time-traveling cyborg, Cable.
#             </p>
#             <p class="">
#              Director:
#              <a href="/name/nm0500610/?ref_=adv_li_dr_0">
#               David Leitch
#              </a>
#              <span class="ghost">
#               |
#              </span>
#              Stars:
#              <a href="/name/nm0005351/?ref_=adv_li_st_0">
#               Ryan Reynolds
#              </a>
#              ,
#              <a href="/name/nm0000982/?ref_=adv_li_st_1">
#               Josh Brolin
#              </a>
#              ,
#              <a href="/name/nm1072555/?ref_=adv_li_st_2">
#               Morena Baccarin
#              </a>
#              ,
#              <a href="/name/nm5421877/?ref_=adv_li_st_3">
#               Julian Dennison
#              </a>
#             </p>
#             <p class="sort-num_votes-visible">
#              <span class="text-muted">
#               Votes:
#              </span>
#              <span data-value="351483" name="nv">
#               351,483
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="text-muted">
#               Gross:
#              </span>
#              <span data-value="324,591,735" name="nv">
#               $324.59M
#              </span>
#             </p>
#            </div>
#           </div>
#           <div class="lister-item mode-advanced">
#            <div class="lister-top-right">
#             <div class="ribbonize" data-caller="filmosearch" data-tconst="tt1677720">
#             </div>
#            </div>
#            <div class="lister-item-image float-left">
#             <a href="/title/tt1677720/?ref_=adv_li_i">
#              <img alt="Ready Player One" class="loadlate" data-tconst="tt1677720" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BY2JiYTNmZTctYTQ1OC00YjU4LWEwMjYtZjkwY2Y5MDI0OTU3XkEyXkFqcGdeQXVyNTI4MzE4MDU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#             </a>
#            </div>
#            <div class="lister-item-content">
#             <h3 class="lister-item-header">
#              <span class="lister-item-index unbold text-primary">
#               4.
#              </span>
#              <a href="/title/tt1677720/?ref_=adv_li_tt">
#               Ready Player One
#              </a>
#              <span class="lister-item-year text-muted unbold">
#               (2018)
#              </span>
#             </h3>
#             <p class="text-muted ">
#              <span class="certificate">
#               PG-13
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="runtime">
#               140 min
#              </span>
#              <span class="ghost">
#               |
#              </span>
#              <span class="genre">
#               Action, Adventure, Sci-Fi
#              </span>
#             </p>
#             <div class="ratings-bar">
#              <div class="inline-block ratings-imdb-rating" data-value="7.5" name="ir">
#               <span class="global-sprite rating-star imdb-rating">
#               </span>
#               <strong>
#                7.5
#               </strong>
#              </div>
#              <div class="inline-block ratings-user-rating">
#               <span class="userRatingValue" data-tconst="tt1677720" id="urv_tt1677720">
#                <span class="global-sprite rating-star no-rating">
#                </span>
#                <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">
#                 Rate this
#                </span>
#               </span>
#               <div class="starBarWidget" id="sb_tt1677720">
#                <div class="rating rating-list" data-auth="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt1677720|imdb|7.5|7.5|||advsearch|title" itemprop="aggregateRating" itemscope="" ite

# %% [markdown]
# ### Each title is in a div class called 'lister-item mode-advanced' and each div have all the data we need.
#
# store the first 50 title containers to get informations.

# %%
# Storing movies informations in a variable
movie_containers = html.find_all('div', class_ = 'lister-item mode-advanced')
# Checking how many movies we have (should be 50)
print(len(movie_containers))
# Out:
# 50

# %% [markdown]
# # Extracting the data
#
# ## 1- Movie name

# %%
# Getting information from the first movie in the containers
first_movie = movie_containers[0]
# output of HTML
print(first_movie.prettify())
# Out:
# <div class="lister-item mode-advanced">
#  <div class="lister-top-right">
#   <div class="ribbonize" data-caller="filmosearch" data-tconst="tt4154756">
#   </div>
#  </div>
#  <div class="lister-item-image float-left">
#   <a href="/title/tt4154756/?ref_=adv_li_i">
#    <img alt="Avengers: Infinity War" class="loadlate" data-tconst="tt4154756" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#   </a>
#  </div>
#  <div class="lister-item-content">
#   <h3 class="lister-item-header">
#    <span class="lister-item-index unbold text-primary">
#     1.
#    </span>
#    <a href="/title/tt4154756/?ref_=adv_li_tt">
#     Avengers: Infinity War
#    </a>
#    <span class="lister-item-year text-muted unbold">
#     (2018)
#    </span>
#   </h3>
#   <p class="text-muted ">
#    <span class="certificate">
#     PG-13
#    </span>
#    <span class="ghost">
#     |
#    </span>
#    <span class="runtime">
#     149 min
#    </span>
#    <span class="ghost">
#     |
#    </span>
#    <span class="genre">
#     Action, Adventure, Fantasy
#    </span>
#   </p>
#   <div class="ratings-bar">
#    <div class="inline-block ratings-imdb-rating" data-value="8.5" name="ir">
#     <span class="global-sprite rating-star imdb-rating">
#     </span>
#     <strong>
#      8.5
#     </strong>
#    </div>
#    <div class="inline-block ratings-user-rating">
#     <span class="userRatingValue" data-tconst="tt4154756" id="urv_tt4154756">
#      <span class="global-sprite rating-star no-rating">
#      </span>
#      <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">
#       Rate this
#      </span>
#     </span>
#     <div class="starBarWidget" id="sb_tt4154756">
#      <div class="rating rating-list" data-auth="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt4154756|imdb|8.5|8.5|||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.5/10 (589,794 votes) - click stars to rate">
#       <meta content="8.5" itemprop="ratingValue"/>
#       <meta content="10" itemprop="bestRating"/>
#       <meta content="589794" itemprop="ratingCount"/>
#       <span class="rating-bg">
#       </span>
#       <span class="rating-imdb " style="width: 119px">
#       </span>
#       <span class="rating-stars">
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          1
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          2
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          3
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          4
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          5
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          6
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          7
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          8
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          9
#         </span>
#        </a>
#        <a href="/register/login?why=vote&amp;ref_=tt_ov_rt" rel="nofollow" title="Register or login to rate this title">
#         <span>
#          10
#         </span>
#        </a>
#       </span>
#       <span class="rating-rating ">
#        <span class="value">
#         8.5
#        </span>
#        <span class="grey">
#         /
#        </span>
#        <span class="grey">
#         10
#        </span>
#       </span>
#       <span class="rating-cancel ">
#        <a href="/title/tt4154756/vote?v=X;k=" rel="nofollow" title="Delete">
#         <span>
#          X
#         </span>
#        </a>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div class="inline-block ratings-metascore">
#     <span class="metascore favorable">
#      68
#     </span>
#     Metascore
#    </div>
#   </div>
#   <p class="text-muted">
#    The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.
#   </p>
#   <p class="">
#    Directors:
#    <a href="/name/nm0751577/?ref_=adv_li_dr_0">
#     Anthony Russo
#    </a>
#    ,
#    <a href="/name/nm0751648/?ref_=adv_li_dr_1">
#     Joe Russo
#    </a>
#    <span class="ghost">
#     |
#    </span>
#    Stars:
#    <a href="/name/nm0000375/?ref_=adv_li_st_0">
#     Robert Downey Jr.
#    </a>
#    ,
#    <a href="/name/nm1165110/?ref_=adv_li_st_1">
#     Chris Hemsworth
#    </a>
#    ,
#    <a href="/name/nm0749263/?ref_=adv_li_st_2">
#     Mark Ruffalo
#    </a>
#    ,
#    <a href="/name/nm0262635/?ref_=adv_li_st_3">
#     Chris Evans
#    </a>
#   </p>
#   <p class="sort-num_votes-visible">
#    <span class="text-muted">
#     Votes:
#    </span>
#    <span data-value="589794" name="nv">
#     589,794
#    </span>
#    <span class="ghost">
#     |
#    </span>
#    <span class="text-muted">
#     Gross:
#    </span>
#    <span data-value="678,815,482" name="nv">
#     $678.82M
#    </span>
#   </p>
#  </div>
# </div>

# %% [markdown]
# #### The movie name is in the first h3 tag
#
# ```
#   <h3 class="lister-item-header">
#    <span class="lister-item-index unbold text-primary">
#     1.
#    </span>
#    <a href="/title/tt4154756/?ref_=adv_li_tt">
#     Avengers: Infinity War
#    </a>
#    <span class="lister-item-year text-muted unbold">
#     (2018)
#    </span>
#   </h3>
# ```

# %%
print(first_movie.h3.prettify())
# Out:
# <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">
#   1.
#  </span>
#  <a href="/title/tt4154756/?ref_=adv_li_tt">
#   Avengers: Infinity War
#  </a>
#  <span class="lister-item-year text-muted unbold">
#   (2018)
#  </span>
# </h3>

# %% [markdown]
# #### The movie name is in the first anchor tag
#
# ```
#  <a href="/title/tt4154756/?ref_=adv_li_tt">
#   Avengers: Infinity War
#  </a>
# ```

# %%
print(first_movie.h3.a.prettify())
# Out:
# <a href="/title/tt4154756/?ref_=adv_li_tt">
#  Avengers: Infinity War
# </a>

# %% [markdown]
# #### Getting the text only from the tag

# %%
print(first_movie.h3.a.text)
# Out:
# Avengers: Infinity War

# %% [markdown]
# ## 2- Movie Year
#
# #### The movie year is stored in the second span with class called 'lister-item-year text-muted unbold' in the h3 tag
#
# ```
#   <h3 class="lister-item-header">
#    <span class="lister-item-index unbold text-primary">
#     1.
#    </span>
#    <a href="/title/tt4154756/?ref_=adv_li_tt">
#     Avengers: Infinity War
#    </a>
#    <span class="lister-item-year text-muted unbold">
#     (2018)
#    </span>
#   </h3>
# ```

# %%
print(first_movie.h3.find('span', class_= 'lister-item-year text-muted unbold').prettify())
# Out:
# <span class="lister-item-year text-muted unbold">
#  (2018)
# </span>

# %% [markdown]
# #### Getting the text from the span

# %%
first_movie.h3.find('span', class_= 'lister-item-year text-muted unbold').text
# Out:
# '(2018)'

# %% [markdown]
# #### Removing text and getting only the digits and converting to int

# %%
int(first_movie.h3.find('span', class_= 'lister-item-year text-muted unbold').text.strip('(IIIVX) '))
# Out:
# 2018

# %% [markdown]
# #### Double Checking

# %%
movie_containers[17].h3.find('span', class_= 'lister-item-year text-muted unbold').text
# Out:
# '(I) (2018)'

# %%
int(movie_containers[17].h3.find('span', class_= 'lister-item-year text-muted unbold').text.strip('(IIIVX) '))
# Out:
# 2018

# %% [markdown]
# ## 3- Rating
#
# #### The rating is within a strong tag within a div class called 'inline-block ratings-imdb-rating' within a div called 'ratings-bar'
# ```
#   <div class="ratings-bar">
#    <div class="inline-block ratings-imdb-rating" data-value="8.5" name="ir">
#     <span class="global-sprite rating-star imdb-rating">
#     </span>
#     <strong>
#      8.5
#     </strong>
#    </div>
# ```

# %%
print(first_movie.strong.prettify())
# Out:
# <strong>
#  8.5
# </strong>

# %% [markdown]
# #### get the text and convert it to float type

# %%
float(first_movie.strong.text)
# Out:
# 8.5

# %% [markdown]
# ## 4- Meta score
#
# #### The meta score is within a span class called 'metascore favorable' within a div class called 'inline-block ratings-metascore within a div class called 'ratings-bar'
# ```
#    <div class="inline-block ratings-metascore">
#     <span class="metascore favorable">
#      68
#     </span>
#     Metascore
#    </div>
# ```

# %%
print(first_movie.find('span', 'metascore favorable').prettify())
# Out:
# <span class="metascore favorable">
#  68
# </span>

# %% [markdown]
# #### Get the text and convert it to int type

# %%
int(first_movie.find('span', 'metascore favorable').text)
# Out:
# 68

# %% [markdown]
# ## 5- Number of votes
#
# #### The number of votes is within a span name attribute with the value 'nv' within a paragraph class called 'sort-num_votes-visible'
# ```
#   <p class="sort-num_votes-visible">
#    <span class="text-muted">
#     Votes:
#    </span>
#    <span data-value="589140" name="nv">
#     589,140
#    </span>
#    <span class="ghost">
#     |
#    </span>
#    <span class="text-muted">
#     Gross:
#    </span>
#    <span data-value="678,815,482" name="nv">
#     $678.82M
#    </span>
#   </p>
# ```

# %%
print(first_movie.find('span', attrs = {'name':'nv'}).prettify())
# Out:
# <span data-value="589752" name="nv">
#  589,752
# </span>

# %% [markdown]
# #### Getting the number of votes without a comma from the 'data-value' attribute

# %%
print(first_movie.find('span', attrs = {'name':'nv'})['data-value'])
# Out:
# 589752

# %% [markdown]
# #### Convert number of votes to int type

# %%
int(first_movie.find('span', attrs = {'name':'nv'})['data-value'])
# Out:
# 589752

# %% [markdown]
# ## 6- Genre
#
# #### The genre is inside a span with class 'genre'
#
# ```
#    <span class="genre">
#     Action, Adventure, Fantasy
#    </span>
# ```

# %%
print(first_movie.find('span', 'genre').prettify())
# Out:
# <span class="genre">
#  Action, Adventure, Fantasy
# </span>

# %%
print(first_movie.find('span', 'genre').text.strip())
# Out:
# Action, Adventure, Fantasy

# %% [markdown]
# ## 7- Runtime
#
# #### duration of the movie is in a span with class "runtime"
#
# ```
#    <span class="runtime">
#     149 min
#    </span>
# ```

# %%
first_movie.find('span','runtime').text
# Out:
# '149 min'

# %% [markdown]
# #### Get only the digits and convert to a float

# %%
[float(s) for s in first_movie.find('span','runtime').text.split() if s.isdigit()][0]
# Out:
# 149.0

# %%
''.join([str(s) for s in first_movie.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[0].split(':')[1:]])
# Out:
# 'Anthony Russo, Joe Russo'

# %% [markdown]
# ## 8- Director
#
# #### The directors and the actors of the movie is in a paragraph with class ""
# ```
#   <p class="">
#    Directors:
#    <a href="/name/nm0751577/?ref_=adv_li_dr_0">
#     Anthony Russo
#    </a>
#    ,
#    <a href="/name/nm0751648/?ref_=adv_li_dr_1">
#     Joe Russo
#    </a>
#    <span class="ghost">
#     |
#    </span>
#    Stars:
#    <a href="/name/nm0000375/?ref_=adv_li_st_0">
#     Robert Downey Jr.
#    </a>
#    ,
#    <a href="/name/nm1165110/?ref_=adv_li_st_1">
#     Chris Hemsworth
#    </a>
#    ,
#    <a href="/name/nm0749263/?ref_=adv_li_st_2">
#     Mark Ruffalo
#    </a>
#    ,
#    <a href="/name/nm0262635/?ref_=adv_li_st_3">
#     Chris Evans
#    </a>
#   </p>
# ```

# %%
print(first_movie.find_all('p','')[2].text.strip('\n'))
# Out:
#     Directors:
# Anthony Russo,
# Joe Russo
# |
#     Stars:
# Robert Downey Jr.,
# Chris Hemsworth,
# Mark Ruffalo,
# Chris Evans

# %% [markdown]
# #### Splitting directors from actors

# %%
print(first_movie.find_all('p','')[2].text.strip('\n').split('|')[0].split(':')[1:])
# Out:
# ['\nAnthony Russo, \nJoe Russo\n']

# %% [markdown]
# #### Removing '\n' and '[ ]' from the text and

# %%
''.join([str(s) for s in first_movie.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[0].split(':')[1:]])
# Out:
# 'Anthony Russo, Joe Russo'

# %% [markdown]
# ## 9- Actor
#
# #### Getting the actors

# %%
print(first_movie.find_all('p','')[2].text.strip('\n'))
# Out:
#     Directors:
# Anthony Russo,
# Joe Russo
# |
#     Stars:
# Robert Downey Jr.,
# Chris Hemsworth,
# Mark Ruffalo,
# Chris Evans

# %% [markdown]
# #### Splitting actors from directors

# %%
print(first_movie.find_all('p','')[2].text.strip('\n').split('|')[1].split(':')[1:])
# Out:
# ['\nRobert Downey Jr., \nChris Hemsworth, \nMark Ruffalo, \nChris Evans']

# %% [markdown]
# #### Removing '\n' and '[ ]' from the text

# %%
''.join([str(s) for s in first_movie.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[1].split(':')[1:]])
# Out:
# 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans'

# %% [markdown]
# ## There's some titles without a meta scores We will assign these values as Null Values(nan).

# %%
type(movie_containers[24].find('div', class_= 'raing-metascore'))
# Out:
# NoneType

# %% [markdown]
# ## Creating a test loop
#
# #### Extract data from each container and put them in their list

# %%
names = []
years = []
imdb_ratings = []
metascores = []
votes = []
genre = []
runtime = []
directors = []
actors = []

# Extracting data from movies
for container in movie_containers:
    

    # Getting the name
    name = container.h3.a.text
    names.append(name)

    # Getting the year
    year = int(container.h3.find('span', class_= 'lister-item-year text-muted unbold').text.strip('(IIIVX) '))
    years.append(year)

    # Getting the rating
    imdb = float(container.strong.text)
    imdb_ratings.append(imdb)

    # Getting the Metascore if the value exist
    if container.find('div', class_ = 'ratings-metascore') is not None:
        m_score = container.find('span', class_ = 'metascore').text
        metascores.append(int(m_score))
    # Else assign in the NaN
    else:
        m_null = np.NaN
        metascores.append(m_null)

    # Getting the number of votes
    vote = container.find('span', attrs = {'name':'nv'})['data-value']
    votes.append(int(vote))
    
    # Getting the genre
    genr = container.find('span', 'genre').text.strip()
    genre.append(genr)
    
    # Getting the duration of the movie
    duration = [float(s) for s in container.find('span','runtime').text.split() if s.isdigit()][0]
    runtime.append(duration)
    
    # Getting the director
    try:
        director = ''.join([str(s) for s in container.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[0].split(':')[1:]])
        directors.append(director)
    except:
        d_null = np.NaN
        directors.append(d_null)
    
    # Getting the actors
    try:
        actor = ''.join([str(s) for s in container.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[1].split(':')[1:]])
        actors.append(actor)
    except:
        a_null = np.NaN
        actors.append(a_null)

# %% [markdown]
# #### Test to check if everything works

# %%
test_df = pd.DataFrame({'movie': names,
                       'year': years,
                       'imdb': imdb_ratings,
                       'metascore': metascores,
                       'votes': votes,
                       'genre': genre,
                       'runtime': runtime,
                       'directors': directors,
                       'actors': actors})
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
# movie        50 non-null object
# year         50 non-null int64
# imdb         50 non-null float64
# metascore    49 non-null float64
# votes        50 non-null int64
# genre        50 non-null object
# runtime      50 non-null float64
# directors    50 non-null object
# actors       50 non-null object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.6+ KB
# None
#                                           movie  year  imdb  metascore  \
# 0                        Avengers: Infinity War  2018   8.5       68.0
# 1                                 Black Panther  2018   7.3       88.0
# 2                                    Deadpool 2  2018   7.8       66.0
# 3                              Ready Player One  2018   7.5       64.0
# 4                                 A Quiet Place  2018   7.6       82.0
# 5                             Bohemian Rhapsody  2018   8.1       49.0
# 6                                         Venom  2018   6.8       35.0
# 7                 Mission: Impossible - Fallout  2018   7.8       86.0
# 8                                  Annihilation  2018   6.9       79.0
# 9                       Solo: A Star Wars Story  2018   7.0       62.0
# 10               Jurassic World: Fallen Kingdom  2018   6.2       51.0
# 11                         Ant-Man and the Wasp  2018   7.1       70.0
# 12                               A Star Is Born  2018   7.9       88.0
# 13                                     Bird Box  2018   6.7       51.0
# 14                                Incredibles 2  2018   7.8       80.0
# 15                                      Aquaman  2018   7.4       55.0
# 16                                  Tomb Raider  2018   6.3       48.0
# 17                                   Game Night  2018   7.0       66.0
# 18                                   Hereditary  2018   7.3       87.0
# 19                                  Red Sparrow  2018   6.6       53.0
# 20                                Ocean's Eight  2018   6.2       61.0
# 21  Fantastic Beasts: The Crimes of Grindelwald  2018   6.8       52.0
# 22                               BlacKkKlansman  2018   7.5       83.0
# 23            Spider-Man: Into the Spider-Verse  2018   8.6       87.0
# 24                                      Rampage  2018   6.1       45.0
# 25                                    First Man  2018   7.4       84.0
# 26                                      The Meg  2018   5.7       46.0
# 27                                 Isle of Dogs  2018   7.9       82.0
# 28                                      Upgrade  2018   7.6       67.0
# 29                  Maze Runner: The Death Cure  2018   6.2       50.0
# 30                                   Green Book  2018   8.3       69.0
# 31                              The Equalizer 2  2018   6.8       50.0
# 32                  Sicario: Day of the Soldado  2018   7.1       61.0
# 33                                 The Predator  2018   5.4       48.0
# 34                        Pacific Rim: Uprising  2018   5.6       44.0
# 35                                         Roma  2018   7.9       96.0
# 36                   Black Mirror: Bandersnatch  2018   7.3        NaN
# 37                                    Searching  2018   7.7       71.0
# 38                            Crazy Rich Asians  2018   7.0       74.0
# 39                      The Cloverfield Paradox  2018   5.6       37.0
# 40                                      The Nun  2018   5.4       46.0
# 41                                 The Commuter  2018   6.3       56.0
# 42                                    Halloween  2018   6.7       67.0
# 43                                  Love, Simon  2018   7.7       72.0
# 44                 The Ballad of Buster Scruggs  2018   7.3       79.0
# 45                                          Tag  2018   6.6       56.0
# 46                                   Skyscraper  2018   5.9       51.0
# 47                                The Favourite  2018   7.8       90.0
# 48                               A Simple Favor  2018   6.9       67.0
# 49                   Bad Times at the El Royale  2018   7.2       60.0
#
#      votes                         genre  runtime  \
# 0   589794    Action, Adventure, Fantasy    149.0
# 1   465635     Action, Adventure, Sci-Fi    134.0
# 2   351483     Action, Adventure, Comedy    119.0
# 3   280860     Action, Adventure, Sci-Fi    140.0
# 4   277419        Drama, Horror, Mystery     90.0
# 5   266565       Biography, Drama, Music    134.0
# 6   237328                Action, Sci-Fi    112.0
# 7   216271   Action, Adventure, Thriller    147.0
# 8   213081      Adventure, Drama, Horror    115.0
# 9   206432    Action, Adventure, Fantasy    135.0
# 10  199246     Action, Adventure, Sci-Fi    128.0
# 11  198434     Action, Adventure, Comedy    118.0
# 12  191714         Drama, Music, Romance    136.0
# 13  188006         Drama, Horror, Sci-Fi    124.0
# 14  180266  Animation, Action, Adventure    118.0
# 15  171340    Action, Adventure, Fantasy    143.0
# 16  154364    Action, Adventure, Fantasy    119.0
# 17  150795         Action, Comedy, Crime    100.0
# 18  132764        Drama, Horror, Mystery    127.0
# 19  128765       Action, Drama, Thriller    140.0
# 20  128726         Action, Comedy, Crime    110.0
# 21  125210    Adventure, Family, Fantasy    134.0
# 22  112897       Biography, Crime, Drama    135.0
# 23  109905  Animation, Action, Adventure    117.0
# 24  107275     Action, Adventure, Sci-Fi    107.0
# 25   98645     Biography, Drama, History    141.0
# 26   98489        Action, Horror, Sci-Fi    113.0
# 27   98088  Animation, Adventure, Comedy    101.0
# 28   91940      Action, Sci-Fi, Thriller    100.0
# 29   85787      Action, Sci-Fi, Thriller    143.0
# 30   84776      Biography, Comedy, Drama    130.0
# 31   84555       Action, Crime, Thriller    121.0
# 32   84404          Action, Crime, Drama    122.0
# 33   84326     Action, Adventure, Sci-Fi    107.0
# 34   84116     Action, Adventure, Sci-Fi    111.0
# 35   82699                         Drama    135.0
# 36   81653        Drama, Mystery, Sci-Fi     90.0
# 37   81491      Drama, Mystery, Thriller    102.0
# 38   80061               Comedy, Romance    120.0
# 39   79569        Drama, Horror, Mystery    102.0
# 40   79297     Horror, Mystery, Thriller     96.0
# 41   77641     Action, Mystery, Thriller    105.0
# 42   77061              Horror, Thriller    106.0
# 43   75788        Comedy, Drama, Romance    110.0
# 44   73307        Comedy, Drama, Musical    133.0
# 45   72706                        Comedy    100.0
# 46   70803   Action, Adventure, Thriller    102.0
# 47   70288      Biography, Comedy, Drama    119.0
# 48   70137          Comedy, Crime, Drama    117.0
# 49   68512         Crime, Drama, Mystery    141.0
#
#                                         directors  \
# 0                        Anthony Russo, Joe Russo
# 1                                    Ryan Coogler
# 2                                    David Leitch
# 3                                Steven Spielberg
# 4                                  John Krasinski
# 5                                    Bryan Singer
# 6                                 Ruben Fleischer
# 7                           Christopher McQuarrie
# 8                                    Alex Garland
# 9                                      Ron Howard
# 10                                    J.A. Bayona
# 11                                    Peyton Reed
# 12                                 Bradley Cooper
# 13                                   Susanne Bier
# 14                                      Brad Bird
# 15                                      James Wan
# 16                                    Roar Uthaug
# 17         John Francis Daley, Jonathan Goldstein
# 18                                      Ari Aster
# 19                               Francis Lawrence
# 20                                      Gary Ross
# 21                                    David Yates
# 22                                      Spike Lee
# 23  Bob Persichetti, Peter Ramsey, Rodney Rothman
# 24                                    Brad Peyton
# 25                                Damien Chazelle
# 26                                 Jon Turteltaub
# 27                                   Wes Anderson
# 28                                 Leigh Whannell
# 29                                       Wes Ball
# 30                                 Peter Farrelly
# 31                                  Antoine Fuqua
# 32                                Stefano Sollima
# 33                                    Shane Black
# 34                             Steven S. DeKnight
# 35                                 Alfonso Cuarón
# 36                                    David Slade
# 37                                Aneesh Chaganty
# 38                                     Jon M. Chu
# 39                                    Julius Onah
# 40                                    Corin Hardy
# 41                             Jaume Collet-Serra
# 42                             David Gordon Green
# 43                                  Greg Berlanti
# 44                          Ethan Coen, Joel Coen
# 45                                    Jeff Tomsic
# 46                        Rawson Marshall Thurber
# 47                               Yorgos Lanthimos
# 48                                      Paul Feig
# 49                                   Drew Goddard
#
#                                                actors
# 0   Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 1   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 2   Ryan Reynolds, Josh Brolin, Morena Baccarin, J...
# 3   Tye Sheridan, Olivia Cooke, Ben Mendelsohn, Le...
# 4   Emily Blunt, John Krasinski, Millicent Simmond...
# 5     Rami Malek, Lucy Boynton, Gwilym Lee, Ben Hardy
# 6   Tom Hardy, Michelle Williams, Riz Ahmed, Scott...
# 7   Tom Cruise, Henry Cavill, Ving Rhames, Simon Pegg
# 8   Natalie Portman, Jennifer Jason Leigh, Tessa T...
# 9   Alden Ehrenreich, Woody Harrelson, Emilia Clar...
# 10  Chris Pratt, Bryce Dallas Howard, Rafe Spall, ...
# 11  Paul Rudd, Evangeline Lilly, Michael Peña, Wal...
# 12  Lady Gaga, Bradley Cooper, Sam Elliott, Greg G...
# 13  Sandra Bullock, Trevante Rhodes, John Malkovic...
# 14  Craig T. Nelson, Holly Hunter, Sarah Vowell, H...
# 15  Jason Momoa, Amber Heard, Willem Dafoe, Patric...
# 16  Alicia Vikander, Dominic West, Walton Goggins,...
# 17  Jason Bateman, Rachel McAdams, Kyle Chandler, ...
# 18  Toni Collette, Milly Shapiro, Gabriel Byrne, A...
# 19  Jennifer Lawrence, Joel Edgerton, Matthias Sch...
# 20  Sandra Bullock, Cate Blanchett, Anne Hathaway,...
# 21  Eddie Redmayne, Katherine Waterston, Dan Fogle...
# 22  John David Washington, Adam Driver, Laura Harr...
# 23  Shameik Moore, Jake Johnson, Hailee Steinfeld,...
# 24  Dwayne Johnson, Naomie Harris, Malin Akerman, ...
# 25  Ryan Gosling, Claire Foy, Jason Clarke, Kyle C...
# 26  Jason Statham, Bingbing Li, Rainn Wilson, Clif...
# 27  Bryan Cranston, Koyu Rankin, Edward Norton, Bo...
# 28  Logan Marshall-Green, Melanie Vallejo, Steve D...
# 29  Dylan O'Brien, Ki Hong Lee, Kaya Scodelario, T...
# 30  Viggo Mortensen, Mahershala Ali, Linda Cardell...
# 31  Denzel Washington, Pedro Pascal, Ashton Sander...
# 32  Benicio Del Toro, Josh Brolin, Isabela Moner, ...
# 33  Boyd Holbrook, Trevante Rhodes, Jacob Tremblay...
# 34  John Boyega, Scott Eastwood, Cailee Spaeny, Bu...
# 35  Yalitza Aparicio, Marina de Tavira, Diego Cort...
# 36  Fionn Whitehead, Craig Parkinson, Alice Lowe, ...
# 37   John Cho, Debra Messing, Joseph Lee, Michelle La
# 38  Constance Wu, Henry Golding, Michelle Yeoh, Ge...
# 39  Gugu Mbatha-Raw, David Oyelowo, Daniel Brühl, ...
# 40  Demián Bichir, Taissa Farmiga, Jonas Bloquet, ...
# 41  Liam Neeson, Vera Farmiga, Patrick Wilson, Jon...
# 42  Jamie Lee Curtis, Judy Greer, Andi Matichak, J...
# 43  Nick Robinson, Jennifer Garner, Josh Duhamel, ...
# 44  Tim Blake Nelson, Willie Watson, Clancy Brown,...
# 45    Jeremy Renner, Ed Helms, Jake Johnson, Jon Hamm
# 46  Dwayne Johnson, Neve Campbell, Chin Han, Rolan...
# 47  Olivia Colman, Emma Stone, Rachel Weisz, Nicho...
# 48  Anna Kendrick, Blake Lively, Henry Golding, An...
# 49  Jeff Bridges, Cynthia Erivo, Dakota Johnson, J...

# %% [markdown]
# #### Check if metascore assigned as nan

# %%
np.isnan(metascores[24])
# Out:
# True

# %% [markdown]
# ## Creating the scaper loop for movies between 2000 and 2018.
#
# #### scrape 6 pages in each year (300 titles)

# %%
pages = [str(i) for i in range(1,252,50)]
pages
# Out:
# ['1', '51', '101', '151', '201', '251']

# %% [markdown]
# #### Scrape titles released between 2000-01-01 and 2018-12-31

# %%
years_url = [str(i) for i in range(2000,2019)]
years_url
# Out:
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %% [markdown]
# #### Pause the loop to sleep for 8 to 15 seconds randomly and observe the requests speed to not crash the server

# %%
start_time = time()
requests = 0

for _ in range(5):
    # Pause the loop for 8~15 seconds
    sleep(randint(8,15))
    # Observing request/speed
    requests += 1
    current_time = time()
    elapsed_time = current_time - start_time
    # Print out request/speed
    print('Request: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    # Stack the output
    clear_output(wait = True)
# Out:
# Request: 5; Frequency: 0.11108007121024784 requests/s

# %% [markdown]
# # Putting everything together and creating the scraper

# %%
names = []
years = []
imdb_ratings = []
metascores = []
votes = []
genre = []
runtime = []
directors = []
actors = []

start_time = time()
requests = 0

for year_url in years_url:

    # For every page 
    for page in pages:

        # Make a get request
        response = get('https://www.imdb.com/search/title?title_type=feature&release_date='+ year_url +
                       '-01-01,'+ year_url +'-12-31&sort=num_votes,desc&start='+ page +'&ref_=adv_nxt')

        # Pause the loop for 8~15 seconds
        sleep(randint(8,15))

        # observe the requests
        requests += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        # Stack the output
        clear_output(wait = True)

        # Put a warning if != 200 status codes
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requests, response.status_code))

        # Break the loop if the number of requests is over 210
        if requests > 115:
            warn('Number of requests was greater than expected.')  
            break 

        # Parse the url with BeautifulSoup
        page_html = BeautifulSoup(response.text, 'html.parser')

        # Creating movie container for all 50 titles
        title_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')

        # For every title
        for container in movie_containers:
            
            # Getting the name
            name = container.h3.a.text
            names.append(name)

            # Getting the year
            year = int(container.h3.find('span', class_= 'lister-item-year text-muted unbold').text.strip('(IIIVX) '))
            years.append(year)

            # Getting the rating
            imdb = float(container.strong.text)
            imdb_ratings.append(imdb)

            # Getting the Metascore if the value exist
            if container.find('div', class_ = 'ratings-metascore') is not None:
                m_score = container.find('span', class_ = 'metascore').text
                metascores.append(int(m_score))
            # Else assign in the NaN
            else:
                m_null = np.NaN
                metascores.append(m_null)

            # Getting the number of votes
            vote = container.find('span', attrs = {'name':'nv'})['data-value']
            votes.append(int(vote))
            
            # Getting the genre
            genr = container.find('span', 'genre').text.strip()
            genre.append(genr)

            # Getting the duration of the movie
            duration = [float(s) for s in container.find('span','runtime').text.split() if s.isdigit()][0]
            runtime.append(duration)

            # Getting the director
            try:
                director = ''.join([str(s) for s in container.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[0].split(':')[1:]])
                directors.append(director)
            except:
                d_null = np.NaN
                directors.append(d_null)

            # Getting the actors
            try:
                actor = ''.join([str(s) for s in container.find_all('p','')[2].text.replace('\n','').strip('\n').split('|')[1].split(':')[1:]])
                actors.append(actor)
            except:
                a_null = np.NaN
                actors.append(a_null)

end_time = time()
# Print out how many seconds it took to run the loop
print(end_time - start_time)
# Out:
# 1510.5643990039825

# %%
print((end_time - start_time)/60)
# Out:
# 25.176073316733042

# %% [markdown]
# #### It took 25~ minutes
#
# ## Storing the data into a dataframe

# %%
df_imdb = pd.DataFrame({'name': names,
                        'year': years,
                        'rating': imdb_ratings,
                        'metascore': metascores,
                        'votes': votes,
                        'genre': genre,
                        'runtime': runtime,
                        'directors': directors,
                        'actors': actors})
print(df_imdb.info())
df_imdb.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5700 entries, 0 to 5699
# Data columns (total 9 columns):
# name         5700 non-null object
# year         5700 non-null int64
# rating       5700 non-null float64
# metascore    4717 non-null float64
# votes        5700 non-null int64
# genre        5700 non-null object
# runtime      5700 non-null float64
# directors    5700 non-null object
# actors       5699 non-null object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 400.9+ KB
# None
#                      name  year  rating  metascore    votes  \
# 0               Gladiator  2000     8.5       67.0  1189368
# 1                 Memento  2000     8.5       80.0  1015315
# 2                  Snatch  2000     8.3       55.0   707814
# 3     Requiem for a Dream  2000     8.3       68.0   689233
# 4                   X-Men  2000     7.4       64.0   527059
# 5               Cast Away  2000     7.8       73.0   465710
# 6         American Psycho  2000     7.6       64.0   423075
# 7             Unbreakable  2000     7.3       62.0   336931
# 8        Meet the Parents  2000     7.0       73.0   290397
# 9  Mission: Impossible II  2000     6.1       59.0   286808
#
#                          genre  runtime           directors  \
# 0     Action, Adventure, Drama    155.0        Ridley Scott
# 1            Mystery, Thriller    113.0   Christopher Nolan
# 2                Comedy, Crime    104.0         Guy Ritchie
# 3                        Drama    102.0    Darren Aronofsky
# 4    Action, Adventure, Sci-Fi    104.0        Bryan Singer
# 5    Adventure, Drama, Romance    143.0     Robert Zemeckis
# 6                 Crime, Drama    101.0         Mary Harron
# 7       Drama, Mystery, Sci-Fi    106.0  M. Night Shyamalan
# 8              Comedy, Romance    108.0           Jay Roach
# 9  Action, Adventure, Thriller    123.0            John Woo
#
#                                               actors
# 0  Russell Crowe, Joaquin Phoenix, Connie Nielsen...
# 1  Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, ...
# 2  Jason Statham, Brad Pitt, Benicio Del Toro, De...
# 3  Ellen Burstyn, Jared Leto, Jennifer Connelly, ...
# 4  Patrick Stewart, Hugh Jackman, Ian McKellen, F...
# 5    Tom Hanks, Helen Hunt, Paul Sanchez, Lari White
# 6  Christian Bale, Justin Theroux, Josh Lucas, Bi...
# 7  Bruce Willis, Samuel L. Jackson, Robin Wright,...
# 8  Ben Stiller, Robert De Niro, Teri Polo, Blythe...
# 9  Tom Cruise, Dougray Scott, Thandie Newton, Vin...

# %%
df_imdb.tail(10)
# Out:
#                            name  year  rating  metascore  votes  \
# 5690                      A-X-L  2018     5.2       29.0   5286
# 5691       The Holiday Calendar  2018     5.7        NaN   5223
# 5692             Mary Magdalene  2018     5.8       47.0   5201
# 5693               Accident Man  2018     6.1        NaN   5158
# 5694               Patient Zero  2018     4.4        NaN   5157
# 5695              The Con Is On  2018     4.6        NaN   5136
# 5696    Paul, Apostle of Christ  2018     6.7       52.0   5126
# 5697              The Domestics  2018     5.7        NaN   5121
# 5698            Geetha Govindam  2018     7.9        NaN   5084
# 5699  La nuit a dévoré le monde  2018     6.0       50.0   5071
#
#                             genre  runtime          directors  \
# 5690    Action, Adventure, Family     98.0        Oliver Daly
# 5691               Drama, Romance     95.0      Bradley Walsh
# 5692                        Drama    120.0        Garth Davis
# 5693      Action, Crime, Thriller    105.0   Jesse V. Johnson
